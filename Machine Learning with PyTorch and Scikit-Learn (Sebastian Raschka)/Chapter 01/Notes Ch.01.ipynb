# %% [markdown]
# # Ch.01: Giving Computers the Ability to Learn from Data

# %% [markdown]
# ## ▶ Building intelligent machines to transform data into knowledge

# %% [markdown]
#  - **We have in abundance: a large amount of structured and unstructured data. In the second half of the 20th century, machine learning evolved as a subfield of artificial intelligence (AI) involving self-learning algorithms that derive knowledge from data to make predictions.**
#  - **machine learning offers a more efficient alternative for capturing the knowledge in data to gradually improve the performance of predictive models and make data-driven decisions.**

# %% [markdown]
# ## ▶The three different types of machine learning

# %% [markdown]
# - **Superviesed Learning (labeled data, Direct feedback, Predict outcome)**
# - **Unsuperviesed Learning (No labeled data, No feedback, Find hidden structure in data)**
# - **Reinforcement Learning (Decision Process, Reward system, Learn series of actions)**

# %% [markdown]
# ## ▶ Making predictions about the future with supervised learning

# %% [markdown]
# ### 1. Classification for predicting class labels
#
# - **Machine learning algorithm learns a set of rules to distinguish between two possible classes: spam and non-spam emails.**
# - **Not only binary class but also multiclass classification**
#
# ### 2. Regression for predicting continuous outcomes
# - **In regression analysis, we are given a number of predictor (explanatory) variables and a continuous response variable (outcome)**
# - **the predictor variables are commonly called “features,” and the response variables are usually referred to as “target variables.”**

# %% [markdown]
# ## ▶ Solving interactive problems with reinforcement learning

# %% [markdown]
# - **the goal is to develop a system (agent) that improves its performance based on interactions with the environment**
# - **we can think of reinforcement learning as a field related to supervised learning but this feedback is a measure of how well the action was measured by a reward function**
# - **An agent can use reinforcement learning to learn a series of actions that maximizes this reward via an exploratory trial-and-error approach or deliberative planning.**
# - **A popular example of reinforcement learning is a chess program.**

# %% [markdown]
# ## ▶ Discovering hidden structures with unsupervised learning

# %% [markdown]
# - **In unsupervised learning, we are dealing with unlabeled data or data of an unknown structure**
# - **we are able to explore the structure of our data to extract meaningful information without the guidance of a known outcome  variable or reward function**

# %% [markdown]
# ## ▶ Finding subgroups with clustering

# %% [markdown]
# - **Clustering is an exploratory data analysis or pattern discovery technique that allows us to organize a pile of information into meaningful subgroups (clusters) without having any prior knowledge of their group memberships.**

# %% [markdown]
# ## ▶ Dimensionality reduction for data compression

# %% [markdown]
# - **Subfield of unsupervised learning is dimensionality reduction**
# - **Unsupervised dimensionality reduction is a commonly used approach in feature preprocessing to remove noise from data**
# - **Dimensionality reduction compresses the data onto a smaller dimensional subspace while retaining most of the relevant information.**

# %% [markdown]
# ## ▶ Machine learning terminology

# %% [markdown]
# - **`Training example:`** A row in a table representing the dataset and synonymous with an observation, record, instance, or sample (in most contexts, sample refers to a collection of training examples).
#
# - **`Training:`** Model fitting, for parametric models similar to parameter estimation.
#
# - **`Feature, abbrev. x:`** A column in a data table or data (design) matrix. Synonymous with predictor, variable, input, attribute, or covariate.
#
# - **`Target, abbrev. y:`** Synonymous with outcome, output, response variable, dependent variable,(class) label, and ground truth.
#
# - **`Loss function:`** Often used synonymously with a cost function. Sometimes the loss function is also called an error function. In some literature, the term “loss” refers to the loss measured for a single data point, and the cost is a measurement that computes the loss (average or summed) over the entire dataset.

# %% [markdown]
# ## ▶ A roadmap for building machine learning systems

# %%
from IPython.display import Image
Image(filename='./Images/01_09.png', width=700)

# %% [markdown]
# ## ▶ Python and packages from the Python Package Index

# %%
# !python --version
# Out:
# Python 3.9.7

# %%
import numpy
numpy.__version__
# Out:
# '1.20.3'

# %%
import scipy
scipy.__version__
# Out:
# '1.7.1'

# %%
import pandas
pandas.__version__
# Out:
# '1.3.4'

# %% [markdown]
# ======================================================================================================================
